# %%
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [6,7,8,9,10]
c = ['r','b','y','g']
plt.bar(x,y,color=c)
plt.show()

# %%
x = ['python','c++','java','c']
y = [85,60,45,98]
plt.figure(figsize=(5,5))
plt.xlabel('language')
plt.ylabel('no')
plt.title('wscode')
c = ['y','g','b','r']
plt.bar(x,y,width=0.2,color=c,align='center',edgecolor='m',linewidth=5,linestyle=':',alpha=0.4)
plt.show()

# %%
x = ['python','c++','java','c']
y = [85,60,45,98]
plt.figure(figsize=(5,5))
plt.xlabel('language')
plt.ylabel('no')
plt.title('wscode')
c = ['y','g','b','r']
plt.bar(x,y,width=0.2,color=c,edgecolor='r',label='wscode')
plt.legend()
plt.show()

# %%
x = ['python','c++','java','c']
y = [85,60,45,98]
z = [20,30,40,50]
plt.figure(figsize=(5,5))
plt.xlabel('language')
plt.ylabel('no')
plt.title('wscode')
plt.bar(x,y,width=0.2,color='r',edgecolor='r',label='wscode')
plt.bar(x,z,width=0.2,color='m',edgecolor='r',label='wscode')
plt.legend()
plt.show()

# %%
import numpy as np
x = ['python','c++','java','c']
y = [85,60,45,98]
z = [20,30,40,50]

width= 0.2
p = np.arange(len(x))
p1=[j+width for j in p]

plt.figure(figsize=(5,5))
plt.xlabel('language')
plt.ylabel('no')
plt.title('wscode')

plt.bar(p,y,width=0.2,color='r',edgecolor='r',label='wscode')
plt.bar(p1,z,width=0.2,color='m',edgecolor='r',label='wscode')

plt.xticks(p+width/2,x)
plt.legend()
plt.show()

# %%
import numpy as np
x = ['python','c++','java','c']
y = [85,60,45,98]
z = [20,30,40,50]

width= 0.2
p = np.arange(len(x))
p1=[j+width for j in p]

plt.figure(figsize=(5,5))
plt.xlabel('language')
plt.ylabel('no')
plt.title('wscode')

plt.barh(p,y,color='r',edgecolor='r',label='wscode')
plt.bar(p1,z,color='m',edgecolor='r',label='wscode')

plt.xticks(p+width/2,x)
plt.legend()
plt.show()

# %%
import numpy as np
x = ['python','c++','java','c']
y = [85,60,45,98]
z = [20,30,40,50]

width= 0.2
p = np.arange(len(x))
p1=[j+width for j in p]

plt.figure(figsize=(5,5))
plt.xlabel('language')
plt.ylabel('no')
plt.title('wscode')

plt.barh(p,y,color='r',edgecolor='r',label='wscode')
plt.barh(p1,z,color='m',edgecolor='r',label='wscode')

plt.xticks(p+width/2,x)
plt.legend()
plt.show()

# %% [markdown]
# # Scater

# %%
day = [1,2,3,4,5,6,7]
no = [2,3,1,4,5,6,8]
colors = ['r','y','b','k','w','y','r']
size = [60,22,33,44,56,44,30]

plt.figure(figsize=(4,4))

plt.scatter(day,no,c=colors,s=size,alpha=0.5,marker="+",edgecolor='g',linewidth=8)
plt.xlabel('day')
plt.ylabel('no')
plt.title('scater plot')

plt.show()
# Out:
# C:\Users\kg317\AppData\Local\Temp\ipykernel_14488\1597189126.py:8: UserWarning: You passed a edgecolor/edgecolors ('g') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(day,no,c=colors,s=size,alpha=0.5,marker="+",edgecolor='g',linewidth=8)

# %%
day = [1,2,3,4,5,6,7]
no = [2,3,1,4,5,6,8]
colors = [20,30,40,50,57,87,45]
size = [60,22,33,44,56,44,30]

plt.figure(figsize=(4,4))

plt.scatter(day,no,c=colors,s = size,cmap='viridis')
plt.colorbar()
plt.xlabel('day')
plt.ylabel('no')
plt.title('scater plot')

plt.show()

# %% [markdown]
# #

# %% [markdown]
# # Histogram plot

# %%
import numpy as np
x = np.random.random((4,4))
x
# Out:
# array([[0.99772052, 0.49371978, 0.89547322, 0.01798691],
#        [0.95669327, 0.91938896, 0.89619499, 0.99952039],
#        [0.35013644, 0.8279575 , 0.38709471, 0.6508205 ],
#        [0.55834975, 0.36245222, 0.85993501, 0.19125892]])

# %%
a =[0.14923748, 0.41001539, 0.7405008 , 0.74411452,
       0.20558562, 0.31384176, 0.6400861 , 0.05772477,
       0.34851484, 0.02046032, 0.74296473, 0.8797155 ,
       0.13763893, 0.83265713, 0.21799728, 0.76074043]
plt.figure(figsize=(4,2))
plt.hist(a,color='r',edgecolor='w')
plt.title('wscode')
plt.xlabel('python')
plt.ylabel('no')
plt.show()

# %% [markdown]
# # Pie plot

# %%
x = [10,20,30,40,50]
y = ['c','python','c++','java','html']
ex=[0.0,0.4,0.0,0.0,0.0]
c = ['r','y','b','k','g']
plt.figure(figsize=(4,4))
plt.pie(x,labels=y,explode=ex,colors=c,autopct="%0.1f%%",shadow=True,radius=1,labeldistance=0.2)

plt.show()

# %%
x = [10,20,30,40,50]
y = ['c','python','c++','java','html']
x1 = [40,50,60,70,80]
c = ['r','y','b','k','g']
plt.figure(figsize=(3,3))
plt.pie(x,labels=y,radius=1.5)
plt.pie([1],colors='w')


plt.show()

# %% [markdown]
# # stem plot

# %%
x = [1,2,3,4,5]
y = [2,4,12,8,10]
plt.figure(figsize=(3,2))
plt.stem(x,y,linefmt=':',markerfmt="ro",bottom=0,basefmt='g',label='python',use_line_collection=False)
plt.legend()
plt.show()
# Out:
# C:\Users\kg317\AppData\Local\Temp\ipykernel_14488\3179598081.py:4: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x,y,linefmt=':',markerfmt="ro",bottom=0,basefmt='g',label='python',use_line_collection=False)

# %% [markdown]
# # box plot

# %%
x = [20,30,40,10,50,60,120]

plt.figure(figsize=(4,2))
plt.boxplot(x,labels=['python'],patch_artist=True,showmeans=True)
plt.show()

# %%
x = [20,30,40,10,50,60,120]
x1 = [10,20,30,40,50,60,70]
y = [x,x1]

plt.figure(figsize=(4,2))
plt.boxplot(y,labels=['python','c++']
            ,showmeans=True,sym='g',boxprops=dict(color='r'),capprops=dict(color='r'),whiskerprops=dict(color='r'))
plt.show()

# %% [markdown]
# # Area plot

# %%
x = [1,2,3,4,5]
area1 = [2,3,2,5,4]
area2 = [2,4,6,8,3]
area3 = [3,5,4,7,8]

l = ['area1','area2','area3']
plt.figure(figsize=(3,2))
plt.stackplot(x,area1,area2,area3,labels=l,colors=['r','g','b'])
plt.title('python')
plt.xlabel('x-axis')
plt.legend(loc=2)
plt.show()

# %% [markdown]
# # step plot

# %%
x = [1,2,3,4,5,6]
y = [2,2,3,6,4,7]

plt.figure(figsize=(3,2))
plt.step(x,y,color='r',marker='o',ms=10,mfc='g',label='python')
plt.title('python')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend(loc=2)
plt.grid()
plt.show()

# %% [markdown]
# # fill_between

# %%
x = np.array([1,2,3,4,5])
y = np.array([1,2,3,4,5])

plt.plot(x,y,color='k')
plt.fill_between(x,y,color='r')
plt.title('python')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %% [markdown]
# # subplot plot

# %%
# plt.subplot(nrows,ncols,index)

# %%
x = [1,2,3,4]
y = [1,2,3,4]
plt.subplot(2,2,1)
plt.plot(x,y,color='r')

plt.subplot(2,2,2)
plt.pie([1],colors='r')

x1=[10,20,30,40]
plt.subplot(2,2,3)
plt.pie(x)

x2 = ['a','s','d','t']
y2 = [10,20,30,40]
plt.subplot(2,2,4)
plt.bar(x2,y2)


plt.show()

# %% [markdown]
# # Text in Matplotlib Plots

# %%
x = [1,2,3,4,5]
y = [3,1,5,2,6]

plt.plot(x,y)

plt.title('graph')
plt.xlabel('day')
plt.ylabel('python')

plt.text(2,5,'java',fontsize=15,style='italic',bbox={'facecolor':'red'})
plt.annotate('python',xy=(2,1),xytext=(3,3),arrowprops=dict(facecolor="black",shrink=100))
plt.legend(['up'],loc=9,facecolor='red',edgecolor='yellow',framealpha=0.5,shadow=True)

plt.show()
